# %%
import pandas as pd
import os

# %%
file_in = "file_in/2012000469_totaal.csv"

# %%
df = pd.read_csv(file_in,";", index_col='Artnr')
artikel_nummers_verzameld=df.groupby('Artnr').sum()

artikel_nummers_verzameld.to_csv("arg.csv", encoding='utf-8')

# %%
aantal_rollen = len(df)
aantal_rollen
# Out:
# 292

# %%
'''hoe krijg ik de eerste in een lijst zonder te hard coden?'''
art_lijst=[]
count = 1
art_lijst.append(f'{df.index[0]}') # hard coded eerste regel
for i in range(1, aantal_rollen):
    
    if df.index[i] != df.index[i-1]:
        count += 1
         
        art_lijst.append(f'{df.index[i]}')

# %%
art_lijst
aantal_rollen = len(art_lijst)
# Out:
# 42

# %%
a=0
b=7
for x in range(0, aantal_rollen):
     
    
    df.iloc[a:b].to_csv(f"{str(x).zfill(4)}.csv", ";")
    
    a+=7
    b+=7

# %%
# str(name).zfill(4)
txt_list = [f"{str(name).zfill(4)}.csv" for name in range(71)]

# %%
for file in txt_list:
    
    
    df_csv=pd.read_csv(file, delimiter=";",usecols=['Artnr','beeld','Aantal','Size','ColorN'])
    new_df = f'{file}_{sum(df_csv.Aantal[0:7])}'
    new_df_a = f'{file}_{sum(df_csv.Aantal[0:3])}_a'
    new_df_b = f'{file}_b'
    new_df_c = f'{file}_c'
    new_df_d = f'{file}_d'
    
   
    
    
    if sum(df_csv.Aantal) > 5000 and sum(df_csv.Aantal) < 10000:
        print(f'gesplitste csv_file: {file} ===> {df_csv.Artnr[0]} --> {sum(df_csv.Aantal)} in 3 delen = {sum(df_csv.Aantal[0:3])} / {sum(df_csv.Aantal[3:5])} / {sum(df_csv.Aantal[5:7])}')
        new_df_a = pd.DataFrame(df_csv[0:3])
        new_df_b = pd.DataFrame(df_csv[3:5])
        new_df_c = pd.DataFrame(df_csv[5:7])
#         print(new_df_a)
#         print(new_df_b)
#         print(new_df_c)
        
        new_df_a.to_csv('tmp1/A'+file+"a.csv", ";", encoding="utf-8")
        new_df_b.to_csv('tmp1/A'+file+"b.csv", ";", encoding="utf-8")
        new_df_c.to_csv('tmp1/A'+file+"c.csv", ";", encoding="utf-8")
        
    elif sum(df_csv.Aantal) > 10000:
        print(f'gesplitste csv_file: {file} ===> {df_csv.Artnr[0]} --> {sum(df_csv.Aantal)} in 4 delen = {sum(df_csv.Aantal[0:2])} / {sum(df_csv.Aantal[2:3])} / {sum(df_csv.Aantal[3:5])} / {sum(df_csv.Aantal[5:7])}')
        new_df_a = pd.DataFrame(df_csv[0:2])
        new_df_b = pd.DataFrame(df_csv[2:3])
        new_df_c = pd.DataFrame(df_csv[3:5])
        new_df_d = pd.DataFrame(df_csv[5:7])
#         print(new_df_a)
#         print(new_df_b)
#         print(new_df_c)
        
        new_df_a.to_csv('tmp1/A'+file+"a.csv", ";", encoding="utf-8")
        new_df_b.to_csv('tmp1/A'+file+"b.csv", ";", encoding="utf-8")
        new_df_c.to_csv('tmp1/A'+file+"c.csv", ";", encoding="utf-8")
        new_df_d.to_csv('tmp1/A'+file+"d.csv", ";", encoding="utf-8")
        
        
        
    else:
        print(f'csv_file: {file} ===> {df_csv.Artnr[0]} --> {sum(df_csv.Aantal)}')
        new_df = pd.DataFrame(df_csv[0:7])
        new_df.to_csv('tmp1/A'+file, ";", encoding="utf-8")
# Out:
# csv_file: 0000.csv ===> 91551-20 --> 474
# csv_file: 0001.csv ===> 91552-20 --> 2844
# gesplitste csv_file: 0002.csv ===> 93625-20 --> 7685 in 3 delen = 3212 / 3277 / 1196
# csv_file: 0003.csv ===> 93626-20 --> 4595
# csv_file: 0004.csv ===> 93630-20 --> 3301
# csv_file: 0005.csv ===> 93631-20 --> 1447
# csv_file: 0006.csv ===> 93640-20 --> 2951
# gesplitste csv_file: 0007.csv ===> 93642-20 --> 7291 in 3 delen = 2833 / 2960 / 1498
# csv_file: 0008.csv ===> 93643-20 --> 1827
# csv_file: 0009.csv ===> 93644-20 --> 4852
# csv_file: 0010.csv ===> 93645-20 --> 663
# gesplitste csv_file: 0011.csv ===> 93646-20 --> 10729 in 4 delen = 1962 / 2473 / 4582 / 1712
# gesplitste csv_file: 0012.csv ===> 93647-20 --> 8312 in 3 delen = 3319 / 3540 / 1453
# csv_file: 0013.csv ===> 93648-20 --> 2158
# csv_file: 0014.csv ===> 93652-20 --> 852
# csv_file: 0015.csv ===> 93653-20 --> 607
# csv_file: 0016.csv ===> 93654-20 --> 2128
# csv_file: 0017.csv ===> 93656-20 --> 649
# csv_file: 0018.csv ===> 93657-20 --> 1249
# csv_file: 0019.csv ===> 93658-20 --> 2424
# gesplitste csv_file: 0020.csv ===> 93659-20 --> 5493 in 3 delen = 2269 / 2313 / 911
# csv_file: 0021.csv ===> 93661-20 --> 3382
# csv_file: 0022.csv ===> 93663-20 --> 592
# csv_file: 0023.csv ===> 93664-20 --> 1910
# csv_file: 0024.csv ===> 93665-20 --> 1533
# csv_file: 0025.csv ===> 93666-20 --> 399
# csv_file: 0026.csv ===> 93667-20 --> 2661
# csv_file: 0027.csv ===> 93668-20 --> 3168
# csv_file: 0028.csv ===> 93670-20 --> 2524
# csv_file: 0029.csv ===> 93671-20 --> 3219
# csv_file: 0030.csv ===> 93673-20 --> 837
# csv_file: 0031.csv ===> 93675-20 --> 1956
# gesplitste csv_file: 0032.csv ===> 93676-20 --> 8455 in 3 delen = 3716 / 3604 / 1135
# csv_file: 0033.csv ===> 93677-20 --> 1133
# gesplitste csv_file: 0034.csv ===> 93680-20 --> 5618 in 3 delen = 2231 / 2361 / 1026
# csv_file: 0035.csv ===> 93683-20 --> 3160
# csv_file: 0036.csv ===> 93685-20 --> 2117
# gesplitste csv_file: 0037.csv ===> 93686-20 --> 5331 in 3 delen = 2065 / 2179 / 1087
# csv_file: 0038.csv ===> 93687-20 --> 2193
# csv_file: 0039.csv ===> 93688-20 --> 864
# csv_file: 0040.csv ===> 93690-20 --> 375
# gesplitste csv_file: 0041.csv ===> 93691-20 --> 12685 in 4 delen = 2183 / 2870 / 5348 / 2284
# csv_file: 0042.csv ===> 93692-20 --> 1609
# csv_file: 0043.csv ===> 93693-20 --> 3347
# csv_file: 0044.csv ===> 93694-20 --> 1188
# gesplitste csv_file: 0045.csv ===> 93695-20 --> 7429 in 3 delen = 2989 / 3082 / 1358
# csv_file: 0046.csv ===> 93697-20 --> 2787
# gesplitste csv_file: 0047.csv ===> 93698-20 --> 6905 in 3 delen = 2804 / 2775 / 1326
# csv_file: 0048.csv ===> 93699-20 --> 955
# gesplitste csv_file: 0049.csv ===> 93700-20 --> 6227 in 3 delen = 2491 / 2687 / 1049
# csv_file: 0050.csv ===> 93703-20 --> 2855
# gesplitste csv_file: 0051.csv ===> 93705-20 --> 8523 in 3 delen = 3335 / 3658 / 1530
# csv_file: 0052.csv ===> 94561-20 --> 2434
# gesplitste csv_file: 0053.csv ===> 94565-20 --> 10176 in 4 delen = 2118 / 2442 / 4298 / 1318
# csv_file: 0054.csv ===> 94566-20 --> 984
# gesplitste csv_file: 0055.csv ===> 95602-20 --> 6620 in 3 delen = 2712 / 2899 / 1009
# csv_file: 0056.csv ===> 95603-20 --> 1437
# csv_file: 0057.csv ===> 95604-20 --> 623
# csv_file: 0058.csv ===> 95609-20 --> 2063
# csv_file: 0059.csv ===> 96571-20 --> 366
# csv_file: 0060.csv ===> 96572-20 --> 3436
# csv_file: 0061.csv ===> 96573-20 --> 525
# csv_file: 0062.csv ===> 97757-20 --> 1876
# csv_file: 0063.csv ===> 97776-20 --> 3993
# gesplitste csv_file: 0064.csv ===> 97780-20 --> 11268 in 4 delen = 2010 / 2559 / 4768 / 1931
# csv_file: 0065.csv ===> 97786-20 --> 975
# csv_file: 0066.csv ===> 97787-20 --> 1237
# csv_file: 0067.csv ===> 97788-20 --> 3761
# csv_file: 0068.csv ===> 97789-20 --> 1562
# csv_file: 0069.csv ===> 97790-20 --> 843
# csv_file: 0070.csv ===> 97792-20 --> 3493

# %%
def rolls(Aantal, beeld, colorname, Artnr, csv):
    """
    Take line from list and build csv for that line
    """
    
    with open(csv, "a", encoding="utf-8") as fn:
        # open a file to append the strings too
        # print(f".;stans.pdf\n", end='', file=fn)

        print(f'{Artnr} {colorname}: {Aantal} etiketten;leeg.pdf\n', end="", file=fn)
        # these  lines encapsulate the artikel en size 
        print(f";{beeld}" * int(Aantal), end="", file=fn)
        # this line prints the actual beeld.pdf without extra

        print(f"{Artnr} {colorname}: {Aantal} etiketten;leeg.pdf\n", end="", file=fn)
        # these  lines encapsulate the artikel en size 
        
        print(f";stans.pdf\n", end="", file=fn)
        # this line seperates the Sizes by a blanco etiket

# %%
def one_step_(lijst_in, file_out):
    """ laad de lijst met gesplitste files"""
    new_input_list = []

    with open('tmp1/'+lijst_in) as input:
        num = 0
        for line in input:
            line_split = line.split(";")

            new_input_list.append(line_split)
            num += 1
    # print(new_input_list)
    list_length = len(new_input_list)

    beg = 1
    eind = 2
    with open(file_out, 'a', encoding='utf-8') as fh:

        for _ in range(list_length - 1):

            aant = int(new_input_list[beg:eind][0][4])
            pdf = str(new_input_list[beg:eind][0][5])
            size = str(new_input_list[beg:eind][0][3])
            art =  str(new_input_list[beg:eind][0][1])

            rolls(aant, pdf, size, art, file_out)
            
            beg += 1
            eind += 1
      
    with open(file_out, 'a', encoding='utf-8') as fh:
        print(";geel.pdf\n"*8, end='', file=fh)
        # this line seperates the Artikels by a a yellow "wikkel"
        df_csv=pd.read_csv('tmp1/'+lijst_in, delimiter=";",usecols=['Artnr','beeld','Aantal','Size','ColorN'])
        artikel_som = sum(df_csv.Aantal)
        artikel = df_csv.Artnr[0]
        print(f"{artikel_som} van {artikel};leeg.pdf\n", end='', file=fh)
        print(";geel.pdf\n"*8, end='', file=fh)

# %%
lijst_order_in_tmp1 = os.listdir('tmp1')

my_last_file="my_last_file_tmp1.csv"

with open(my_last_file, "w") as fileout:
    print("aantal;beeld", file=fileout)

for list_csv in lijst_order_in_tmp1:
    one_step_(list_csv, my_last_file)
    print(list_csv + ' processed')
# Out:
# A0000.csv processed
# A0001.csv processed
# A0002.csva.csv processed
# A0002.csvb.csv processed
# A0002.csvc.csv processed
# A0003.csv processed
# A0004.csv processed
# A0005.csv processed
# A0006.csv processed
# A0007.csva.csv processed
# A0007.csvb.csv processed
# A0007.csvc.csv processed
# A0008.csv processed
# A0009.csv processed
# A0010.csv processed
# A0011.csva.csv processed
# A0011.csvb.csv processed
# A0011.csvc.csv processed
# A0011.csvd.csv processed
# A0012.csva.csv processed
# A0012.csvb.csv processed
# A0012.csvc.csv processed
# A0013.csv processed
# A0014.csv processed
# A0015.csv processed
# A0016.csv processed
# A0017.csv processed
# A0018.csv processed
# A0019.csv processed
# A0020.csva.csv processed
# A0020.csvb.csv processed
# A0020.csvc.csv processed
# A0021.csv processed
# A0022.csv processed
# A0023.csv processed
# A0024.csv processed
# A0025.csv processed
# A0026.csv processed
# A0027.csv processed
# A0028.csv processed
# A0029.csv processed
# A0030.csv processed
# A0031.csv processed
# A0032.csva.csv processed
# A0032.csvb.csv processed
# A0032.csvc.csv processed
# A0033.csv processed
# A0034.csva.csv processed
# A0034.csvb.csv processed
# A0034.csvc.csv processed
# A0035.csv processed
# A0036.csv processed
# A0037.csva.csv processed
# A0037.csvb.csv processed
# A0037.csvc.csv processed
# A0038.csv processed
# A0039.csv processed
# A0040.csv processed
# A0041.csva.csv processed
# A0041.csvb.csv processed
# A0041.csvc.csv processed
# A0041.csvd.csv processed
# A0042.csv processed
# A0043.csv processed
# A0044.csv processed
# A0045.csva.csv processed
# A0045.csvb.csv processed
# A0045.csvc.csv processed
# A0046.csv processed
# A0047.csva.csv processed
# A0047.csvb.csv processed
# A0047.csvc.csv processed
# A0048.csv processed
# A0049.csva.csv processed
# A0049.csvb.csv processed
# A0049.csvc.csv processed
# A0050.csv processed
# A0051.csva.csv processed
# A0051.csvb.csv processed
# A0051.csvc.csv processed
# A0052.csv processed
# A0053.csva.csv processed
# A0053.csvb.csv processed
# A0053.csvc.csv processed
# A0053.csvd.csv processed
# A0054.csv processed
# A0055.csva.csv processed
# A0055.csvb.csv processed
# A0055.csvc.csv processed
# A0056.csv processed
# A0057.csv processed
# A0058.csv processed
# A0059.csv processed
# A0060.csv processed
# A0061.csv processed
# A0062.csv processed
# A0063.csv processed
# A0064.csva.csv processed
# A0064.csvb.csv processed
# A0064.csvc.csv processed
# A0064.csvd.csv processed
# A0065.csv processed
# A0066.csv processed
# A0067.csv processed
# A0068.csv processed
# A0069.csv processed
# A0070.csv processed
